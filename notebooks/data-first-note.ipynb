# %%
print("hello world")
# Out:
# hello world

# %%
display()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=329149044125048#setting/sparkui/0709-104017-m7a3qdv7/driver-3005748802864921512">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dbutils.fs.mkdirs("/datalake")
# Out:
# Out[5]: True

# %%
dbutils.fs.mkdirs("/datalake/raw")
# Out:
# Out[6]: True

# %%
dbutils.fs.mkdirs("/datalake/curated")
# Out:
# Out[7]: True

# %%
dbutils.fs.mkdirs("/datalake/serving")
# Out:
# Out[8]: True

# %%
dbutils.fs.ls("/")
# Out:
# Out[9]: [FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/datalake/', name='datalake/', size=0, modificationTime=0)]

# %%
dbutils.fs.ls("/datalake")
# Out:
# Out[10]: [FileInfo(path='dbfs:/datalake/curated/', name='curated/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/datalake/raw/', name='raw/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/datalake/serving/', name='serving/', size=0, modificationTime=0)]
