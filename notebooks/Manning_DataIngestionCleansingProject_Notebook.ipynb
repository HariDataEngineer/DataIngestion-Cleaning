# %% [markdown]
# # Data Ingestion and Cleansing
#
# For each milestone, create a notebook that contains the code needed to perform the different steps.
#
# Run the different cells to generate the desired outputs.
